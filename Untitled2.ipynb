# %%
import matplotlib.pyplot as plt
x=[20,24,26,12,29]
y=[30,32,34,31,38]
plt.plot(x,y)
plt.title("Line Chart")
plt.ylabel("y-Axis")
plt.xlabel("x-Axis")

plt.show()

# %%
import pandas as pd
data=pd.read_csv("data.csv",header=0,sep=",")
x=data['Amount']
y=data['Qty']
plt.bar(x,y)
# plt.ylim(ymin=0)
# plt.xlim(xmin=0)
plt.title('Amount vs Qty')
plt.show()

# %%
import pandas as pd
data=pd.read_csv("data.csv",header=0,sep=",")
x=data['Amount']
y=data['Qty']
plt.scatter(x,y)
# plt.ylim(ymin=0)
# plt.xlim(xmin=0)
plt.title('Amount vs Qty')
plt.show()

# %%
import pandas as pd
data=pd.read_csv("data.csv",header=0,sep=",")
x=data['Amount']
y=data['Qty']
plt.hist(x)
# plt.ylim(ymin=0)
# plt.xlim(xmin=0)
plt.title('Amount vs Qty')
plt.show()

# %%
import pandas as pd
import matplotlib
matplotlib.use('TkAgg')
data=pd.read_csv("data.csv",header=0,sep=",")
x=data['Amount']
y=data['Qty']
plt.plot(x='Amount',y='Qty',kind="pie")
# plt.ylim(ymin=0)
# plt.xlim(xmin=0)
plt.title('Amount vs Qty')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 7
#       5 x=data['Amount']
#       6 y=data['Qty']
# ----> 7 plt.plot(x='Amount',y='Qty',kind="pie")
#       8 # plt.ylim(ymin=0)
#       9 # plt.xlim(xmin=0)
#      10 plt.title('Amount vs Qty')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# ...

# %%
import sys
import matplotlib
matplotlib.use('TkAgg')

import pandas as pd
import matplotlib.pyplot as plt

health_data = pd.read_csv("data1.csv", header=0, sep=",")

health_data.plot(x ='Average_Pulse', y='Calorie_Burnage', kind='pie')

plt.title('Pulse vs Calorie graph',color='red',fontsize=50)
plt.show()

# %%
cars=['Audi','Mecedes',"Bmw","toyota"]
data=[20,30,29,48,58]
plt.pie(data,label='cars')
plt.tile("CARDATA")
plt.show()
plt.savefig('hp.jpg')
# plt.savefig('OUTPUT1',facecolor='y',bbox='tight',pad_inches
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 cars=['Audi','Mecedes',"Bmw","toyota"]
#       2 data=[20,30,29,48,58]
# ----> 3 plt.pie(data,label='cars')
#       4 plt.tile("CARDATA")
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
x=[20,24,26,27,29]
y=[30,32,34,37,38]
plt.plot(x,y)
plt.ylim(ymin=0)
plt.xlim(xmin=0)
plt.title('Amount vs Qty')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
fig=plt.figure(figsize=(7,7),facecolor='g',edgecolor="p",linewidth=7)
ax=fig.add_axes([1,1,1,1])

x=[10,29,38,48 ,58,67]
y=[91,82,83,74,75,66]
ax.plot(x,y)
plt.title("linear garph",fontsize=25,color="purple")
plt.ylabel("y-Axis")
plt.xlabel("x-Axis")
plt.ylim(0-100)
plt.xticks(x,labels=["one","two","three","four","five","six"])
plt.legend("linear legacy")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 import matplotlib.pyplot as plt
#       2 from matplotlib.figure import Figure
# ----> 3 fig=plt.figure(figsize=(7,7),facecolor='g',edgecolor="p",linewidth=7)
#       4 ax=fig.add_axes([1,1,1,1])
#       6 x=[10,29,38,48 ,58,67]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
x= [10,20,30,40]
y= [20,25,35,55]
fig = plt.figure(figsize=(7,5), facecolor='y', edgecolor='r',linewidth=7)
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.title("Linear Graph", fontsize=25, color="yellow")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.ylim(0,80)
plt.xticks(x, label=["one", "two", "three", "four"])
plt.legend(["Legend No. 1"])
plt.show()
