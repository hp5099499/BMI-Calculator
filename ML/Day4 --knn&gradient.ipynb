# %% [markdown]
# KNN
#
# feature scaling
# -- Standardization
# -- Normalization
#
# Gradient Descent(Loss&Cost Functions)
#
# Euclidean distance
# d=((x-x1)^2+(y-y1)^2)^1/2

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv('ins.csv')
df.sample(3)
# Out:
#    Age  Income  Spending Insurance
# 3   37      58        30    Health
# 2   23      40        28      Life
# 4   45      61        41    Health

# %%
# features=['Age','Income','Spending']
# x=df['features']

# %%
x=df.drop('Insurance',axis='columns')
y=df['Insurance']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 x=df.drop('Insurance',axis='columns')
#       2 y=df['Insurance']
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['Insurance'] not found in axis"

# %%
Model= KNeighborsClassifier(n_neighbors=3)
Model.fit(x,y)
Model.predict([[28,60,29]])
# Out:
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 3
#       1 Model= KNeighborsClassifier(n_neighbors=3)
#       2 Model.fit(x,y)
# ----> 3 Model.predict([[28,60,29]])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_classification.py:266, in KNeighborsClassifier.predict(self, X)
#     263         return self.classes_[np.argmax(probabilities, axis=1)]
#     264     # In that case, we do not need the distances to perform
#     265     # the weighting so we do not compute them.
# --> 266     neigh_ind = self.kneighbors(X, return_distance=False)
#     267     neigh_dist = None
#     268 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\neighbors\_base.py:804, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     802         X = _check_precomputed(X)
#     803     else:
# --> 804         X = self._validate_data(X, accept_sparse="csr", reset=False, order="C")
#     806 n_samples_fit = self.n_samples_fit_
#     807 if n_neighbors > n_samples_fit:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:626, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
# --> 626     self._check_n_features(X, reset=reset)
#     628 return out
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:415, in BaseEstimator._check_n_features(self, X, reset)
#     412     return
#     414 if n_features != self.n_features_in_:
# --> 415     raise ValueError(
#     416         f"X has {n_features} features, but {self.__class__.__name__} "
#     417         f"is expecting {self.n_features_in_} features as input."
#     418     )
#
# ValueError: X has 3 features, but KNeighborsClassifier is expecting 2 features as input.

# %% [markdown]
# # II-task

# %%
df=pd.read_csv('ins1.csv')
df.sample(5)
# Out:
#     Age  Income Insurance
# 5    42   47926      Life
# 7    22   35600      Life
# 2    50   54512      Life
# 3    29   35133    Health
# 27   60   41405      Life

# %%
x=df.drop('Insurance',axis='columns')
y=df['Insurance']

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.predict([[26,63000]])
# Out:
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Health'], dtype=object)

# %%
knn.fit(x,y)
# Out:
# KNeighborsClassifier()

# %%
df['pred']=knn.predict(x)
df
# Out:
#     Age  Income Insurance    pred
# 0    37   46954      Life  Health
# 1    41   53449    Health  Health
# 2    50   54512      Life  Health
# 3    29   35133    Health    Life
# 4    40   43316    Health  Health
# 5    42   47926      Life  Health
# 6    20   48284    Health  Health
# 7    22   35600      Life    Life
# 8    25   54498    Health  Health
# 9    32   46013    Health  Health
# 10   47   37409      Life    Life
# 11   56   46783    Health  Health
# 12   40   42241      Life    Life
# 13   25   48898    Health  Health
# 14   39   39229    Health  Health
# 15   27   43650      Life  Health
# 16   50   38620    Health  Health
# 17   38   45333      Life  Health
# 18   22   38770    Health  Health
# 19   34   52269    Health  Health
# 20   26   37223      Life    Life
# 21   58   45196    Health  Health
# 22   52   36178      Life    Life
# 23   56   54334    Health  Health
# 24   50   46011    Health  Health
# 25   55   42188      Life    Life
# 26   30   43320    Health  Health
# 27   60   41405      Life  Health
# 28   29   39534    Health  Health
# 29   52   37288    Health    Life
# 30   40   54820      Life  Health
# 31   34   49680    Health  Health
# 32   42   47165      Life    Life
# 33   23   41017    Health    Life
# 34   53   38497    Health  Health
# 35   30   36256      Life    Life
# 36   23   47493    Health    Life
# 37   20   40167      Life  Health
# 38   36   51798    Health  Health
# 39   20   42223    Health    Life
# 40   46   38391      Life  Health
# 41   25   35004    Health    Life
# 42   59   45289      Life  Health
# 43   40   40906    Health    Life
# 44   29   43298    Health  Health
# 45   50   51522      Life  Health
# 46   25   44912    Health  Health
# 47   59   35187      Life    Life
# 48   58   48721    Health  Health

# %%
from sklearn.metrics import accuracy_score
accuracy_score(df['pred'],df['Insurance'])
# Out:
# 0.6326530612244898

# %%
import seaborn as sns
sns.scatterplot(x='Age',y='Income',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
# NORMALISATION
from sklearn.preprocessing import MinMaxScaler
scal=MinMaxScaler()
df1=df.drop(['Insurance','pred'],axis='columns')
a=scal.fit_transform(df1)
a_d=pd.DataFrame(a,columns=df1.columns)
a_d
# Out:
#       Age    Income
# 0   0.425  0.603048
# 1   0.525  0.930813
# 2   0.750  0.984457
# 3   0.225  0.006510
# 4   0.500  0.419459
# 5   0.550  0.652099
# 6   0.000  0.670166
# 7   0.050  0.030077
# 8   0.125  0.983751
# 9   0.300  0.555561
# 10  0.675  0.121367
# 11  0.900  0.594419
# 12  0.500  0.365210
# 13  0.125  0.701151
# 14  0.475  0.213212
# 15  0.175  0.436314
# 16  0.750  0.182479
# 17  0.450  0.521245
# 18  0.050  0.190048
# 19  0.350  0.871266
# 20  0.150  0.111980
# 21  0.950  0.514332
# 22  0.800  0.059245
# 23  0.900  0.975474
# 24  0.750  0.555460
# 25  0.875  0.362535
# 26  0.250  0.419661
# 27  1.000  0.323022
# 28  0.225  0.228603
# 29  0.800  0.115260
# 30  0.500  1.000000
# 31  0.350  0.740614
# 32  0.550  0.613696
# 33  0.075  0.303442
# 34  0.825  0.176272
# 35  0.250  0.063181
# 36  0.075  0.630248
# 37  0.000  0.260547
# 38  0.400  0.847497
# 39  0.000  0.364302
# 40  0.650  0.170922
# 41  0.125  0.000000
# 42  0.975  0.519025
# 43  0.500  0.297840
# 44  0.225  0.418551
# 45  0.750  0.833569
# 46  0.125  0.500000
# 47  0.975  0.009235
# 48  0.950  0.692218

# %%
# Standardization-->ML(regression,CLASSIFICATION)
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
b=s.fit_transform(df1)

# %%
pd.DataFrame(b,columns=df1.columns).sample()
# Out:
#          Age    Income
# 36 -1.244333  0.607563
