# %%
import numpy as np
speed=[23,45,23,45,23,456,657,456,2133,8,663,5523]
x=np.mean(speed)
print(x)
# Out:
# 837.9166666666666

# %%
print(np.median(speed))
# Out:
# 250.5

# %%
pip install scipy
# Out:
#   Cell In[10], line 1
#     pip install scipy
#         ^
# SyntaxError: invalid syntax

# %%
from scipy import stats
print(stats.mode(speed))
# Out:
# ModeResult(mode=23, count=3)

# %%
print(np.std(speed))
# Out:
# 1525.3621678327922

# %%
print(np.var(speed))
# Out:
# 2326729.7430555555

# %%
print(np.percentile(speed,34))
# Out:
# 39.28

# %%
import matplotlib.pyplot as plt
x=np.random.uniform(0.0,5.0,230)
print(x)
plt.hist(x,230)
plt.show()
# Out:
# [4.84952421 1.92207638 4.55698729 0.73366898 3.98677852 1.8643245
#  0.68843727 1.06340125 2.6320359  1.94367176 1.95364828 1.86547468
#  3.49009607 1.97236204 1.81378231 1.56016572 0.19022211 3.98886001
#  4.6482367  0.94586377 1.72720944 3.78048401 3.21640016 1.4752871
#  1.03606374 1.24293965 2.15902495 4.24330628 1.65651887 1.64204068
#  2.79455674 0.36240534 1.99844288 1.11037127 1.8514933  0.68853749
#  1.36556966 0.12056211 1.5349948  1.23824832 2.66973141 0.80940666
#  2.71869071 3.58970738 3.41866707 1.05836944 4.7783128  0.57346719
#  0.26955972 2.44717853 3.53355514 4.44764829 1.61479277 2.2142477
#  4.11618129 0.42035406 3.13566656 0.55155688 3.3433495  4.21700824
#  2.52475767 0.01620402 3.59548794 1.72611399 0.58351115 1.2853253
#  3.80461794 0.66028008 0.4447005  2.03359643 3.6807921  1.1720946
#  0.38248513 0.5558112  2.13827098 3.90315204 3.32518309 2.52038098
#  1.40418898 4.47379213 4.15870325 1.09635279 2.6630319  3.67908153
# ...

# %%
x=np.random.normal(0,5,200000)
print(x)
plt.hist(x,200,color='deepskyblue')
plt.show()
# Out:
# [-0.49821572 -0.90186984 -1.39659673 ...  2.14199557 -2.31101308
#  -1.95292237]

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
colors=('r','g','c','m','hotpink','r','g','c','m','hotpink','r','g','c')
plt.scatter(x, y,color=colors)
plt.show()

# %%
x = np.random.normal(1,9,10)
y =np.random.normal(2,28,10)
# colors=('r','g','c','m','hotpink','r','g','c','m','hotpink','r','g','c')
plt.scatter(x, y)
plt.show()
