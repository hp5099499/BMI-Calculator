# %% [markdown]
# Employee regression

# %% [raw]
# EDA

# %% [raw]
# DATA MINIING

# %%
import pandas as pd
df=pd.read_csv('employees.csv')
df.head(5)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.sample(5)    #random5 data
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 553     Amanda  Female   6/7/2002         7:46 AM  109290   13.853
# 896     Victor    Male  3/10/2010         5:01 PM   45267    3.942
# 686       Paul     NaN  2/18/2011        12:23 PM   91462   18.704
# 689      Julie     NaN   5/8/1980         6:31 AM   50529   17.263
# 955      Sarah  Female  8/17/2014        11:08 PM  127118   11.176
#
#     Senior Management         Team
# 553             False  Engineering
# 896              True        Sales
# 686             False      Finance
# 689             False      Finance
# 955             False        Legal

# %%
df.isnull().all()
# Out:
# First Name           False
# Gender               False
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus %              False
# Senior Management    False
# Team                 False
# dtype: bool

# %%
df.isnull().any()
# Out:
# First Name            True
# Gender                True
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus %              False
# Senior Management     True
# Team                  True
# dtype: bool

# %%
df['Salary'].isnull().any()
# Out:
# False

# %%
df['Bonus %'].isnull().all()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
df['First Name']=df['First Name'].fillna('na')

# %%
df['First Name'].sample(20)
# Out:
# 735     Barbara
# 779       Doris
# 45        Roger
# 190       Carol
# 154     Rebecca
# 614        Eric
# 303        Joan
# 79       Bonnie
# 27        Scott
# 481          na
# 366    Jennifer
# 480         Amy
# 248      Justin
# 317       Kathy
# 269          na
# 172        Sara
# 862      Ronald
# 231       Diane
# 591      Rachel
# 26        Craig
# Name: First Name, dtype: object

# %%
df['First Name']=df['First Name'].replace(to_replace='na',value="good")

# %%
df['First Name'].sample(20)
# Out:
# 876        Terry
# 407        Steve
# 561     Kathleen
# 552      Barbara
# 142    Elizabeth
# 121     Kathleen
# 425        Alice
# 965    Catherine
# 134      Carolyn
# 218      Gregory
# 362       Joshua
# 386      Phyllis
# 734         good
# 26         Craig
# 205      Brandon
# 406         Mary
# 137         Adam
# 91         James
# 446       Cheryl
# 284       Brenda
# Name: First Name, dtype: object

# %%
df.sample(20)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 725     Jeremy    Male   5/19/1991         1:40 PM  131513    1.876
# 538       Adam    Male   10/8/2010         9:53 PM   45181    3.491
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 778    Antonio    Male  12/28/2003         4:17 AM  137979    5.266
# 879        Amy  Female   5/20/2009         6:26 AM   75415   19.132
# 491   Nicholas     NaN    9/9/1989         7:12 PM   58478    6.525
# 328     Samuel    Male  12/19/1991         2:54 AM   76076    5.319
# 629      Debra  Female   3/12/1983        12:19 PM   74911   19.513
# 477     Albert    Male   8/14/2008         5:43 PM  137840    9.705
# 398      Doris  Female   7/29/1992         6:40 PM   85215    7.425
# 193    Rebecca  Female   2/18/1995         6:50 AM  109259    4.443
# 540       good  Female   12/2/2009         3:30 AM   84746    4.820
# 551     Philip    Male   7/18/1985         6:36 AM  122319   19.122
# ...

# %%
df['Gender']=df['Gender'].replace('NaN','not defined')

# %%
df.sample(20)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN   7/11/1991         6:58 PM  122367    5.218
# 402    Richard     NaN  11/28/1992         5:05 PM  124655   14.272
# 309   Benjamin    Male   9/11/1984         6:37 AM   84810   15.794
# 645       Anna     NaN   3/13/1985         9:19 AM   45418   10.162
# 700      Frank    Male    3/2/2009         9:15 PM   78891    7.927
# 154    Rebecca  Female  11/15/1980         4:13 AM   85730    5.359
# 312     Gerald    Male   4/16/2001        10:09 PM  121604    1.923
# 487     Cheryl  Female   12/3/2014         9:27 AM   71751   15.918
# 823       good    Male  11/12/2009         2:30 PM  109411    9.494
# 322    Douglas    Male    1/8/2002         6:42 PM   41428   14.372
# 956    Beverly  Female  10/17/1986        12:51 AM   80838    8.115
# 909     Donald    Male    8/1/1991         2:25 AM   61999    6.466
# 662  Katherine  Female  12/19/2000         1:40 AM   41643    4.659
# ...

# %%
df.head(20)
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2       Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3       Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4       Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5      Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6        Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        good  Female   7/20/2015        10:43 AM   45906   11.598
# 8      Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9     Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   Gender             764 non-null    object
#  2   Start Date         764 non-null    object
#  3   Last Login Time    764 non-null    object
#  4   Salary             764 non-null    int64
#  5   Bonus %            764 non-null    float64
#  6   Senior Management  764 non-null    object
#  7   Team               764 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 53.7+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x='Salary',y='Bonus %',data=df,hue='Gender')
# Out:
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.scatterplot(x='Salary',y='Bonus %',data=df,hue='Senior Management')
# Out:
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.scatterplot(x='Salary',y='Bonus %',data=df,hue='Team')
# Out:
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.pairplot(df)
# Out:
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
pip install ydata_profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ydata_profiling-4.6.1-py2.py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached matplotlib-3.7.3-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached visions-0.7.5-py3-none-any.whl (102 kB)
# ...
#   Using cached phik-0.12.3-cp311-cp311-win_amd64.whl (663 kB)
# ...
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# ...
#   Using cached wordcloud-1.9.2-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# ...
# Using cached ydata_profiling-4.6.1-py2.py3-none-any.whl (357 kB)
# Using cached matplotlib-3.7.3-cp311-cp311-win_amd64.whl (7.5 MB)
# Using cached wordcloud-1.9.2-cp311-cp311-win_amd64.whl (151 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\himanshu\AppData\Roaming\Python\Python311\site-packages)
# ...

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/47/6a/453160888fab7c6a432a6e25f8afe6256d0d9f2cbd25971021da6491d899/pip-23.3.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 660.6 kB/s eta 0:00:04
#     --------------------------------------- 0.0/2.1 MB 660.6 kB/s eta 0:00:04
#    - -------------------------------------- 0.1/2.1 MB 297.7 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/2.1 MB 297.7 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/2.1 MB 327.7 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/2.1 MB 327.7 kB/s eta 0:00:07
# ...

# %%
import ydata_profiling
from ydata_profiling import ProfileReport

# %%
import pandas as pd
df=pd.read_csv('employees.csv')

# %%
a=ProfileReport(df)
a.to_file('a.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
a.to_notebook_iframe()
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-10-26 05:21:28.752494&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
import scipy
x=df[['Salary']]
y=[['Bonus %']]
# from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test=train_test_split(x,y)
# x_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       3 y=[['Bonus %']]
#       4 # from sklearn.model_selection import train_test_split
#       5 # x_train,x_test,y_train,y_test=train_test_split(x,y)
#       6 # x_train.shape
# ----> 7 mukesh.predict()
#
# NameError: name 'mukesh' is not defined

# %%
pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("car_data (1).csv")
df.sample(5)
# Out:
#      User ID  Gender  Age  AnnualSalary  Purchased
# 812      528  Female   37         64500          0
# 395      170  Female   23         28000          0
# 294      741  Female   43         54500          0
# 11       408    Male   47         23000          1
# 318      879    Male   36         73500          0

# %%
# data cleaning
df.isnull().any()
# Out:
# User ID         False
# Gender          False
# Age             False
# AnnualSalary    False
# Purchased       False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User ID       1000 non-null   int64
#  1   Gender        1000 non-null   object
#  2   Age           1000 non-null   int64
#  3   AnnualSalary  1000 non-null   int64
#  4   Purchased     1000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 39.2+ KB

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# redundant data 
import pandas as pd
df=pd.read_csv("car_data (1).csv")
df.drop(['User ID'],axis='columns',inplace=True)

# %%
df['Gender']=df['Gender'].replace({'female':0,'male':1},inplace=True)
print(df['Gender'])
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 995    None
# 996    None
# 997    None
# 998    None
# 999    None
# Name: Gender, Length: 1000, dtype: object

# %%
df.sample()
# Out:
#     Gender  Age  AnnualSalary  Purchased
# 904   Male   37         34500          0

# %%
  sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['Age','Gender','AnnualSalary']],df['Purchased'])
